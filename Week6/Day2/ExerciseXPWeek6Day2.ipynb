# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import describe

# %% [markdown]
# 1.

# %%
array3 = np.random.randint(1,100,size =(3,3))
array3
# Out:
# array([[20, 18, 61],
#        [21, 88, 43],
#        [51, 88, 52]])

# %%
det_A = np.linalg.det(array3)

# %%
det_A
# Out:
# -125381.99999999994

# %%
inverse_array3 = np.linalg.inv(array3)

print("Original Matrix:")
print(array3)
print("\nInverse Matrix:")
print(inverse_array3)
# Out:
# Original Matrix:
# [[20 18 61]
#  [21 88 43]
#  [51 88 52]]
#
# Inverse Matrix:
# [[-0.0063167  -0.03534798  0.03664003]
#  [-0.00878116  0.01651752 -0.00335774]
#  [ 0.02105565  0.00671548 -0.01102232]]

# %% [markdown]
# 2.

# %%
array =
stats = describe(array, axis = 0)
stats
# Out:
# DescribeResult(nobs=3, minmax=(array([42,  6,  6]), array([74, 98, 43])), mean=array([53.        , 43.33333333, 19.66666667]), variance=array([ 331.        , 2341.33333333,  412.33333333]), skewness=array([0.70470423, 0.57364534, 0.67636379]), kurtosis=array([-1.5, -1.5, -1.5]))

# %% [markdown]
# 3.

# %%
dates = np.arange("2023-01-01", "2023-01-31", dtype ='datetime64[D]')
dates
# Out:
# array(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#        '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#        '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#        '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#        '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#        '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#        '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#        '2023-01-29', '2023-01-30'], dtype='datetime64[D]')

# %% [markdown]
# 4.

# %%
data = np.random.randint(10,100,size=(10,5))
data
# Out:
# array([[54, 60, 76, 80, 11],
#        [35, 16, 34, 81, 87],
#        [82, 98, 62, 67, 19],
#        [33, 42, 12, 57, 75],
#        [83, 29, 89, 30, 83],
#        [83, 60, 30, 62, 89],
#        [71, 75, 36, 79, 46],
#        [89, 36, 83, 62, 49],
#        [27, 79, 74, 38, 60],
#        [55, 83, 79, 74, 95]])

# %%
df = pd.DataFrame(data)
df
# Out:
#     0   1   2   3   4
# 0  54  60  76  80  11
# 1  35  16  34  81  87
# 2  82  98  62  67  19
# 3  33  42  12  57  75
# 4  83  29  89  30  83
# 5  83  60  30  62  89
# 6  71  75  36  79  46
# 7  89  36  83  62  49
# 8  27  79  74  38  60
# 9  55  83  79  74  95

# %%
#Conditional selection of data.
df[:5]
# Out:
#     0   1   2   3   4
# 0  54  60  76  80  11
# 1  35  16  34  81  87
# 2  82  98  62  67  19
# 3  33  42  12  57  75
# 4  83  29  89  30  83

# %%
#Conditional selection of data.
df[3:5]
# Out:
#     0   1   2   3   4
# 3  33  42  12  57  75
# 4  83  29  89  30  83

# %%
#Conditional selection of data then using avg aggregation function
df.iloc[3:5, :2].mean()
# Out:
# 0    58.0
# 1    35.5
# dtype: float64

# %%
#Aggregation functions sum
#summing each column
df[:].sum()
# Out:
# 0    612
# 1    578
# 2    575
# 3    630
# 4    614
# dtype: int64

# %% [markdown]
# 5.

# %%
# Create a 5x5 array representing a grayscale image
image = np.array([
    [100, 120, 140, 160, 180],
    [120, 140, 160, 180, 200],
    [140, 160, 180, 200, 220],
    [160, 180, 200, 220, 240],
    [180, 200, 220, 240, 255]
], dtype=np.uint8)

# Display the image using matplotlib
plt.imshow(image, cmap='gray')
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# 6.

# %%
# Productivity scores of employees before the training program
productivity_before = np.random.normal(loc=50, scale=10, size=30)

# Productivity scores of the same employees after the training program
productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)

# Your task is to formulate a hypothesis regarding the training program's effectiveness
# and test it using basic statistical functions in NumPy.

# %%
print(productivity_before)
print(productivity_after)
# Out:
# [57.6640422  31.29762713 35.01427596 54.14552947 56.73676016 45.47560166
#  36.51842585 58.99136587 50.24291479 46.22404867 44.77276677 46.52815039
#  46.87924735 45.95095604 35.59512179 38.63426229 60.20671981 42.34139143
#  58.25281947 53.29479994 55.77268215 64.1244875  64.24209843 46.08650736
#  40.91774955 56.34656625 60.72920807 60.08672447 52.40907982 46.24026875]
# [62.08907435 43.35701312 32.48278114 59.82631919 57.89870977 49.73899895
#  39.54294161 66.6245734  53.98503925 47.53617779 45.53239046 56.52383074
#  54.74352584 47.88455698 41.73699462 44.53092006 67.32403364 46.60291647
#  66.06508248 57.52499006 65.61660907 70.19381423 68.52426257 50.45381681
#  44.93586076 61.28009667 73.30424504 66.29347942 58.99863549 51.43419232]

# %% [markdown]
# - H0 : mean value of before is greater than that of the after dataset
# - H1: The mean value of before dataset is not greater than that of after *dataset*

# %%
before =np.mean(productivity_before)
print("before", before)

after = np.mean(productivity_after)
print("after", after)

if before > after:
  print("we accept the null hypothesis")
else:
  print("we reject the null hypothesis")
# Out:
# before 49.724073313382924
# after 55.086196076538236
# we reject the null hypothesis

# %%
greater_elements = productivity_before > productivity_after
print(greater_elements)
# Out:
# [False False  True False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False]

# %%
dates = np.arange("2023-01-01", "2023-12-31", dtype ='datetime64[D]')
dates

# %%
months = np.datetime_as_string(dates, unit='M')
months

# %%
df_dates = pd.DataFrame({'Date':dates})
df_dates
# Out:
#           Date
# 0   2023-01-01
# 1   2023-01-02
# 2   2023-01-03
# 3   2023-01-04
# 4   2023-01-05
# ..         ...
# 359 2023-12-26
# 360 2023-12-27
# 361 2023-12-28
# 362 2023-12-29
# 363 2023-12-30
#
# [364 rows x 1 columns]

# %%
df_dates["month"] = df_dates["Date"].dt.month
df_dates
# Out:
#           Date  month
# 0   2023-01-01      1
# 1   2023-01-02      1
# 2   2023-01-03      1
# 3   2023-01-04      1
# 4   2023-01-05      1
# ..         ...    ...
# 359 2023-12-26     12
# 360 2023-12-27     12
# 361 2023-12-28     12
# 362 2023-12-29     12
# 363 2023-12-30     12
#
# [364 rows x 2 columns]

# %%
jan_march = df_dates[(df_dates["month"] >= 1) & (df_dates["month"] <= 3)]
jan_march
# Out:
#          Date  month
# 0  2023-01-01      1
# 1  2023-01-02      1
# 2  2023-01-03      1
# 3  2023-01-04      1
# 4  2023-01-05      1
# ..        ...    ...
# 85 2023-03-27      3
# 86 2023-03-28      3
# 87 2023-03-29      3
# 88 2023-03-30      3
# 89 2023-03-31      3
#
# [90 rows x 2 columns]

# %%
apr_jun = df_dates[(df_dates["month"] >= 4) & (df_dates["month"] <= 6)]
apr_jun
# Out:
#           Date  month
# 90  2023-04-01      4
# 91  2023-04-02      4
# 92  2023-04-03      4
# 93  2023-04-04      4
# 94  2023-04-05      4
# ..         ...    ...
# 176 2023-06-26      6
# 177 2023-06-27      6
# 178 2023-06-28      6
# 179 2023-06-29      6
# 180 2023-06-30      6
#
# [91 rows x 2 columns]

# %%
jul_sep = df_dates[(df_dates["month"] >= 7) & (df_dates["month"] <= 9)]
jul_sep
# Out:
#           Date  month
# 181 2023-07-01      7
# 182 2023-07-02      7
# 183 2023-07-03      7
# 184 2023-07-04      7
# 185 2023-07-05      7
# ..         ...    ...
# 268 2023-09-26      9
# 269 2023-09-27      9
# 270 2023-09-28      9
# 271 2023-09-29      9
# 272 2023-09-30      9
#
# [92 rows x 2 columns]

# %%
oct_dec = df_dates[(df_dates["month"] >= 8) & (df_dates["month"] <= 12)]
oct_dec
# Out:
#           Date  month
# 212 2023-08-01      8
# 213 2023-08-02      8
# 214 2023-08-03      8
# 215 2023-08-04      8
# 216 2023-08-05      8
# ..         ...    ...
# 359 2023-12-26     12
# 360 2023-12-27     12
# 361 2023-12-28     12
# 362 2023-12-29     12
# 363 2023-12-30     12
#
# [152 rows x 2 columns]

# %% [markdown]
# 9.

# %%
df= pd.DataFrame({'Date':dates})
df.head()
# Out:
#         Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05

# %%
import matplotlib.pyplot as plt

plt.plot(productivity_before, label = "productivity")
plt.plot(productivity_after, label = "productivity")
plt.show()
