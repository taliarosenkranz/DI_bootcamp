# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.uniform(10, 30, 356)

cities = [
    "Tokyo",
    "New York City",
    "London",
    "Paris",
    "Beijing",
    "Tel Aviv",
    "Jerusalem",
    "Mumbai",
    "Rio de Janeiro",
    "Sydney"
]

month = [ "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

temperatures = np.random.uniform(-5, 35, size=(10, 12))

df = pd.DataFrame(temperatures, index = cities, columns=month)
df.head(10)
# Out:
#                   January   February      March      April        May  \
# Tokyo            6.697186  11.411574  21.669607   6.158917  -2.578657
# New York City   21.184075   5.717304  12.886968  14.189771  34.661334
# London          -0.909085  22.299356   2.894089  17.941245  20.803603
# Paris            8.702696  18.032500   4.606257  22.360470   5.692795
# Beijing         26.096913   6.236626  26.538586  30.081666   1.157621
# Tel Aviv        23.632960  -2.131013   9.956124  33.808246  29.319373
# Jerusalem       17.227798  15.655529  20.008444  30.020709  33.750459
# Mumbai          28.203833  -1.257116  13.262994  19.547904   2.542971
# Rio de Janeiro   9.357835   0.398031  25.894703  -3.984709  21.185385
# Sydney          22.350337  10.982994  10.831114  12.910194   9.092895
#
#                      June       July     August  September    October  \
# Tokyo            7.944997  25.966166  21.208489  13.654750  -3.217833
# ...

# %%
from matplotlib import pyplot as plt
_df_1['February'].plot(kind='hist', bins=20, title='February')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Distribution of temperatures in february. we can see that most cities are between 0 and 6 degrees.

# %%
from matplotlib import pyplot as plt
_df_10['March'].plot(kind='line', figsize=(8, 4), title='March')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Plot shows 5 cities in march and how there temperatures vary. the plot seems volatile as the remperatures in march amongst these cities are quire different. while it is very cold in lonfon, Rio and Beijing are enjoying warmer temperatures.

# %%
df.T.mean()
# Out:
# Tokyo             10.462385
# New York City     13.988872
# London            10.370740
# Paris             14.395994
# Beijing           16.590007
# Tel Aviv          20.851608
# Jerusalem         21.956831
# Mumbai            10.514514
# Rio de Janeiro    13.037260
# Sydney            14.711178
# dtype: float64

# %%
df.mean().sort_values(ascending = False)
# Out:
# April        18.303441
# August       18.245349
# July         17.679151
# September    17.021842
# December     16.396653
# January      16.254455
# May          15.562778
# March        14.854888
# June         14.728234
# October       9.902246
# February      8.734578
# November      8.571649
# dtype: float64

# %% [markdown]
# Based on the data available in this dataset, April has the highest temperatures on average through out all cities while November has the lowest.

# %%
df.mean(axis=1).sort_values(ascending = False)
# Out:
# Jerusalem         21.956831
# Tel Aviv          20.851608
# Beijing           16.590007
# Sydney            14.711178
# Paris             14.395994
# New York City     13.988872
# Rio de Janeiro    13.037260
# Mumbai            10.514514
# Tokyo             10.462385
# London            10.370740
# dtype: float64

# %% [markdown]
# Highest temperatures on average are in Jerusalem closely followed by Tel Aviv. London is representing the lowest temperatures on average anually.
