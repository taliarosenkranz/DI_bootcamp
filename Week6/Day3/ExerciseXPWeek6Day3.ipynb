# %%
from scipy import mean, median, std
from scipy.stats import describe, norm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
scipy.__version__
# Out:
# '1.11.4'

# %%
data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
print(mean(data))
print(median(data))
print(std(data))
# Out:
# 16.625
# 16.5
# 3.8709656418005056
# <ipython-input-11-affadc41c7d7>:1: DeprecationWarning: scipy.mean is deprecated and will be removed in SciPy 2.0.0, use numpy.mean instead
#   print(mean(data))
# <ipython-input-11-affadc41c7d7>:2: DeprecationWarning: scipy.median is deprecated and will be removed in SciPy 2.0.0, use numpy.median instead
#   print(median(data))
# <ipython-input-11-affadc41c7d7>:3: DeprecationWarning: scipy.std is deprecated and will be removed in SciPy 2.0.0, use numpy.std instead
#   print(std(data))

# %%
describe(data)
# Out:
# DescribeResult(nobs=8, minmax=(12, 22), mean=16.625, variance=17.125, skewness=0.06525681329773589, kurtosis=-1.6476734867850917)

# %%
#Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10.
#Plot this distribution.


#mean 50, std 10, number of values 1000
data = np.random.normal(loc=50, scale=10, size=1000)

# Fit a normal distribution to the data
mu, std = norm.fit(data)

# Plot the histogram of the data
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')

# Plot the PDF (Probability Density Function) of the fitted normal distribution
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)

# Add labels and title
plt.title("Fit results: mu = %.2f,  std = %.2f" % (mu, std))
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.show()

# %%
data1 = np.random.normal(loc=0, scale=10, size=1000)
data2 = np.random.normal(loc=50, scale=10, size=1000)

# %%
from scipy.stats import describe, norm,ttest_ind

t_statistic, p_value = ttest_ind(data1, data2)


print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: -113.95647509450083
# P-value: 0.0

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.head()
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
df.quantity.describe()
# Out:
# count    368.000000
# mean      14.565217
# std        8.595740
# min        3.000000
# 25%        8.000000
# 50%       12.000000
# 75%       20.000000
# max       50.000000
# Name: quantity, dtype: float64

# %%
describe(df.quantity)
# Out:
# DescribeResult(nobs=369, minmax=(nan, nan), mean=nan, variance=nan, skewness=nan, kurtosis=nan)

# %%
from scipy.stats import skew, kurtosis
data = np.random.normal(0, 1, 1000)
skewness = skew(data)
kurtosis_value = kurtosis(data)

print("Skewness:", skewness)
print("Kurtosis:", kurtosis_value)
# Out:
# Skewness: 0.15134314923172898
# Kurtosis: 0.16924787240310568
