# %% [markdown]
# 🌟 Exercise 1 : Understanding Data Visualization
# Instructions
# Explain why data visualization is important in data analysis.
# Describe the purpose of a line graph in data visualization.

# %% [markdown]
# when sharing results of Data analysis, it should be like story telling. lots of black numbers are difficult to understand therefore we try to highlight main findings in a visual

# %% [markdown]
# 🌟 Exercise 2 : Creating A Line Plot For Temperature Variation
# Instructions
# Create a simple line plot using Matplotlib that represents the temperature variations over a week.
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]) and label the x-axis as “Day” and the y-axis as “Temperature (°F)”.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
import datetime as dt

# %%
dates = pd.date_range('2024-03-01', periods=7) #7 days of the week
temperatures =  [72, 74, 76, 80, 82, 78, 75]
data = {"Date": dates,"Temperature":temperatures}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#         Date  Temperature
# 0 2024-03-01           72
# 1 2024-03-02           74
# 2 2024-03-03           76
# 3 2024-03-04           80
# 4 2024-03-05           82
# 5 2024-03-06           78
# 6 2024-03-07           75

# %%
plt.figure()
plt.plot(dates, temperatures)
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.xticks(rotation = 45)
plt.title("Dayly temperature variations")
plt.show()

# %% [markdown]
# 🌟 Exercise 3 : Visualizing Monthly Sales With A Bar Chart
#
# Generate a bar chart using Matplotlib to visualize the monthly sales data for a retail store.
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]) and label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.

# %%
dates = pd.date_range('2024-03-01', periods=30)

sales = np.random.randint(5000, 10001, size=30)

data = {"Date": dates,"Sales Amount":sales}

df_sales = pd.DataFrame(data)

# %%
df_sales
# Out:
#          Date  Sales Amount
# 0  2024-03-01          5421
# 1  2024-03-02          6560
# 2  2024-03-03          6890
# 3  2024-03-04          6377
# 4  2024-03-05          7920
# 5  2024-03-06          8338
# 6  2024-03-07          7471
# 7  2024-03-08          6215
# 8  2024-03-09          6988
# 9  2024-03-10          8023
# 10 2024-03-11          6162
# 11 2024-03-12          8442
# 12 2024-03-13          5799
# 13 2024-03-14          5026
# 14 2024-03-15          9285
# 15 2024-03-16          7976
# 16 2024-03-17          7669
# 17 2024-03-18          5424
# 18 2024-03-19          8502
# 19 2024-03-20          5380
# 20 2024-03-21          6983
# 21 2024-03-22          9412
# 22 2024-03-23          6024
# 23 2024-03-24          6397
# 24 2024-03-25          8428
# 25 2024-03-26          5689
# 26 2024-03-27          8797
# 27 2024-03-28          7254
# 28 2024-03-29          7951
# 29 2024-03-30          8263

# %%
plt.figure()
#df_sales.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.bar(dates, sales)
plt.title('monthly sales data for a retail store.')
plt.xlabel('Date')
plt.ylabel('Sales Amount ($)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 🌟 Exercise 4 : Data Visualisation
# Instructions
# Using the dataset sales_data.csv
#
# - Calculate the total quantity of products sold by the company.
# - Identify the category that had the highest revenue and calculate how much revenue it generated.
# - Determine the average revenue per sale in the dataset.
# - Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.head()
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
total_quantity = df["quantity"].sum()
print("total quantity of products sold: ", total_quantity)
# Out:
# total quantity of products sold:  5360.0

# %%
highest_revenue = df.groupby("product")["price"].max()
print(highest_revenue)
total_revenue_laptop = df[df["product"] == 'Laptop']['revenue'].sum()
print("total revenue : ", total_revenue_laptop)
# Out:
# product
# Backpack        50.0
# Coat           100.0
# Headphones     100.0
# Hoodie          40.0
# Jeans           50.0
# Laptop        1200.0
# Smartphone     600.0
# Smartwatch     200.0
# Sneakers        80.0
# Speaker         80.0
# T-Shirt         20.0
# Tablet         400.0
# Wallet          30.0
# Watch          150.0
# Name: price, dtype: float64
# total revenue :  6000.0

# %%
average_revenue_per_sales = df["revenue"].mean()
print("average revenue per sale: ", round(average_revenue_per_sales, 3))
# Out:
# average revenue per sale:  2060.679

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
total_rev_per_month = df.groupby(df["date"].dt.month).sum()
# Out:
# <ipython-input-66-252485e22c9b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_rev_per_month = df.groupby(df["date"].dt.month).sum()

# %%
total_rev_per_quarter = df.groupby(df['date'].dt.quarter).sum()
# Out:
# <ipython-input-74-43b62ebd7bb2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_rev_per_quarter = df.groupby(df['date'].dt.quarter).sum()

# %%
total_rev_per_quarter
# Out:
#         price  quantity   revenue
# date
# 1     19910.0    1322.0  182100.0
# 2     18770.0    1307.0  183970.0
# 3     19420.0    1335.0  197680.0
# 4     19420.0    1396.0  194580.0

# %%
quartiles = ["Q1", "Q2", "Q3", "Q4"]

# %%
plt.figure()
plt.bar(quartiles, total_rev_per_quarter.revenue)
plt.xlabel("Yearly Quarters")
plt.ylabel("Total Revenue")
plt.title("total revenue generated in each quarter of the year")
# Out:
# Text(0.5, 1.0, 'total revenue generated in each quarter of the year')

# %% [markdown]
# 🌟 Exercise 5 : Data Visualisation Using MatPlotLib
# Instructions
# Create a simple line plot using Matplotlib. Plot the function y = x^2 for x values ranging from -10 to 10. Add a title and label the x and y axes.
# Generate a bar chart to display the sales data of four different products (A, B, C, D) in a week. The sales values are 15, 30, 45, and 20 respectively. Label the chart appropriately.
# Create a pie chart representing the following data about favorite fruits of a group of people: Apples (40%), Bananas (30%), Cherries (20%), and Dates (10%). Customize the chart with different colors for each fruit and add a legend.

# %%
x = np.linspace(-10, 10)
y = x ** 2

# %%
plt.figure()
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("a title")
plt.show()

# %%
x = ["A", "B", "C", "D"]
y = [15, 30, 45, 20]

# %%
plt.figure()
plt.bar(x,y)
plt.xlabel("products")
plt.ylabel("sales")
# Out:
# Text(0, 0.5, 'sales')

# %%
fruit = ["Apples", "Bananas","Cherries", "Dates"]
market_share = [40,30, 20, 10]

plt.figure()
plt.pie(market_share, labels=fruit)
plt.title("favorite fruits of a group of people")
plt.legend(loc='best')
plt.show()
