# %% [markdown]
# 🌟 Exercise 1 : Visualizing The Distribution Of CGPA

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from preprocessing import pregame

# %%
df = pd.read_csv("Student Mental health.csv")

# %%
pre = pregame(df)

# %%
df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
categories = df["What is your course?"].unique()
categories
# Out:
# array(['Engineering', 'Islamic education', 'BIT', 'Laws', 'Mathemathics',
#        'Pendidikan islam', 'BCS', 'Human Resources', 'Irkhs',
#        'Psychology', 'KENMS', 'Accounting ', 'ENM', 'Marine science',
#        'KOE', 'Banking Studies', 'Business Administration', 'Law',
#        'KIRKHS', 'Usuluddin ', 'TAASL', 'Engine', 'ALA',
#        'Biomedical science', 'koe', 'Kirkhs', 'BENL', 'Benl', 'IT', 'CTS',
#        'engin', 'Econs', 'MHSC', 'Malcom', 'Kop', 'Human Sciences ',
#        'Biotechnology', 'Communication ', 'Diploma Nursing',
#        'Pendidikan Islam ', 'Radiography', 'psychology', 'Fiqh fatwa ',
#        'DIPLOMA TESL', 'Koe', 'Fiqh', 'Islamic Education', 'Nursing ',
#        'Pendidikan Islam'], dtype=object)

# %%
sns.histplot(df["What is your CGPA?"], color = "skyblue")
plt.xticks(rotation = 45)
plt.title(" CGPA categories.")
plt.show()

# %% [markdown]
# 🌟 Exercise 2: Comparing Anxiety Levels Across Different Genders

# %%
df
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
df = df.rename(columns={'What is your CGPA?':'CGPA','Your current year of Study':'Year of study','Choose your gender':'Gender','Do you have Depression?':'Depression','Do you have Anxiety?':'Anxiety','Do you have Panic attack?':'Panic attack','Did you seek any specialist for a treatment?':'treatment'})

# %%
df = df.copy()

# %%
mental_health_across_gender = df.groupby('Gender')['Anxiety'].value_counts('Yes').reset_index(name='Count')

# %%
mental_health_across_gender
# Out:
#    Gender Anxiety     Count
# 0  Female      No  0.680000
# 1  Female     Yes  0.320000
# 2    Male      No  0.615385
# 3    Male     Yes  0.384615

# %%
sns.barplot(data=mental_health_across_gender, x='Gender', y='Count', hue='Anxiety')
plt.title("Mental health across gender")
plt.show()

# %%
df["Choose your gender"].value_counts()
# Out:
# Female    75
# Male      26
# Name: Choose your gender, dtype: int64

# %%
df.columns
# Out:
# Index(['Timestamp', 'Gender', 'Age', 'What is your course?', 'Year of study',
#        'CGPA', 'Marital status', 'Depression', 'Anxiety', 'Panic attack',
#        'treatment'],
#       dtype='object')

# %%
#replace all columns that have yes no values
#pre.binary_exchange('Yes', 'No') #yes = 1 , no = 0
df["Panic attack"].replace({"Yes": 1, "No": 0}, inplace = True)

# %%
y=df['Panic attack']
x=df['Age']

# %%
plt.scatter(x, y)

# %%
panick_across_age = df.groupby('Age')['Panic attack'].value_counts("Yes").reset_index(name='Count')

# %%
panick_across_age
# Out:
#      Age Panic attack     Count
# 0   18.0           No  0.718750
# 1   18.0          Yes  0.281250
# 2   19.0           No  0.571429
# 3   19.0          Yes  0.428571
# 4   20.0           No  0.833333
# 5   20.0          Yes  0.166667
# 6   21.0           No  1.000000
# 7   22.0           No  1.000000
# 8   23.0           No  0.615385
# 9   23.0          Yes  0.384615
# 10  24.0           No  0.608696
# 11  24.0          Yes  0.391304

# %%
#plt.scatter(panick_across_age["Age"], panick_across_age['Count'])
sns.lmplot(x = "Age", y ='Count', data=panick_across_age, hue='Panic attack')
plt.show()

# %%
#only runs when replacing yes and no with 1 0
sns.lmplot(x = "Age", y ='Count', data=panick_across_age, hue='Panic attack')
plt.show()

# %%
subset= ["Age", "CGPA", "Depression", "Anxiety", "Panic attack"]
df_subset = df[subset]
df_subset.head()
# Out:
#     Age         CGPA Depression Anxiety Panic attack
# 0  18.0  3.00 - 3.49        Yes      No          Yes
# 1  21.0  3.00 - 3.49         No     Yes           No
# 2  19.0  3.00 - 3.49        Yes     Yes          Yes
# 3  22.0  3.00 - 3.49        Yes      No           No
# 4  23.0  3.00 - 3.49         No      No           No

# %%
pre=pregame(df_subset)
pre.binary_exchange("Yes", "No")
# Out:
# /content/preprocessing.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df[column].replace({string1: 1, string2: 0}, inplace = True)
#       Age         CGPA  Depression  Anxiety  Panic attack
# 0    18.0  3.00 - 3.49           1        0             1
# 1    21.0  3.00 - 3.49           0        1             0
# 2    19.0  3.00 - 3.49           1        1             1
# 3    22.0  3.00 - 3.49           1        0             0
# 4    23.0  3.00 - 3.49           0        0             0
# ..    ...          ...         ...      ...           ...
# 96   21.0  3.50 - 4.00           0        1             0
# 97   18.0  3.00 - 3.49           1        1             0
# 98   19.0  3.50 - 4.00           1        0             1
# 99   23.0  3.50 - 4.00           0        0             0
# ...

# %%
sns.pairplot(df_subset, hue="Depression", markers ="o")

# %%
correlation_matrix = df_subset.corr()
# Out:
# <ipython-input-181-272ea798f274>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_subset.corr()

# %%
correlation_matrix
# Out:
#                    Age  Depression   Anxiety  Panic attack
# Age           1.000000   -0.072171 -0.093661      0.055741
# Depression   -0.072171    1.000000  0.273764      0.246842
# Anxiety      -0.093661    0.273764  1.000000      0.084478
# Panic attack  0.055741    0.246842  0.084478      1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, vmin=-1, vmax=1)
plt.title("correlation between self reportet mental health status of students")
plt.show()

# %%
g = sns.FacetGrid(df, col="Depression", row="CGPA")
g.map(sns.scatterplot, "Depression", "Age")

plt.show()
