# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px
from plotnine import ggplot, aes, geom_point, labs

# %%
df = sns.load_dataset('iris')

# %% [markdown]
# Matplotlib Task: Generate a histogram for petal lengths.

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.hist(df["petal_length"],bins=5, alpha=0.7, color='blue', edgecolor='black')
plt.title("Distribution of petal length")
plt.show()

# %% [markdown]
# Seaborn Task: Produce a pair plot to show pairwise relationships in the dataset.

# %%
sns.pairplot(df, hue="species", markers ="o")
plt.title("pairwise relationship between iris data variables")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# Plotnine Task: Create a scatter plot of sepal length vs. sepal width, color-coded by species.

# %%
plot = (ggplot(df, aes(x='sepal_length', y='sepal_width', color='species'))
        + geom_point()
        + labs(title='Sepal Length vs. Sepal Width by Species', x='Sepal Length (cm)', y='Sepal Width (cm)'))
print(plot)

# %% [markdown]
# Plotly Task: Create an interactive 3D scatter plot mapping sepal length, sepal width, and petal length, color-coded by species.

# %%
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_length',
                    color='species', title='3D Scatter Plot of Iris Dataset')

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
