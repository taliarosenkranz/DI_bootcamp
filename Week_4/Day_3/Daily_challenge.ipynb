# %%
import pandas as pd

# %%
df = pd.read_csv("IRIS.csv")

# %% [markdown]
# 1.

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# 2. Data Cleaning - Handling Missing Values: Check for missing values in the dataset and decide how to handle them. You can either remove rows with missing values or impute them with appropriate values (e.g., using the mean or median). Document your approach and execute it.

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.fillna(df.median())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     785         try:
# --> 786             values = values.astype("f8")
#     787         except ValueError as err:
#
# ValueError: could not convert string to float: 'Iris-setosa'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-dac89757a4d4> in <module>
# ----> 1 df.fillna(df.median())
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11621             **kwargs,
#   11622         ):
# > 11623             return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11624
# ...

# %% [markdown]
# 3. Data Cleaning - Renaming Columns: Examine the column names in the dataset. If needed, rename the columns to make them more descriptive and meaningful. For example, you can rename columns like ‘sepal_length’ and ‘sepal_width’ for clarity.

# %%
df.rename(columns = {"sepal_length":"Sepal_Length","sepal_width":"Sepal_Width"}, inplace = True)

# %% [markdown]
# 4. Export to Excel: After cleaning the dataset, export it to a new Excel file (e.g., cleaned_iris.xlsx) using Pandas. Ensure that the exported file contains the cleaned data with updated column names.

# %%
df.to_excel("cleaned_iris.xlsx", index=False)
# Out:
# <ipython-input-4-874cdda9ffcf>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   df.to_excel("cleaned_iris.xlsx", index=False)

# %% [markdown]
# 5. Import from Excel: Import the data from the Excel file (cleaned_iris.xlsx) back into a Python DataFrame. Verify that the imported data matches the cleaned data from step 2.

# %%
df_new = pd.read_excel("cleaned_iris.xlsx")

# %%
df_new
# Out:
#      Sepal_Length  Sepal_Width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# if not specifying index false when exporting the file, then when importing the file a new index column is added
#df_clean.drop("Unnamed: 0", axis=1)
# Out:
#      Sepal_Length  Sepal_Width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 6. Import from Excel: Import the data from the Excel file (cleaned_iris.xlsx) back into a Python DataFrame. Verify that the imported data matches the cleaned data from step 2.

# %%
df_clean == df_new
# Out:
#      Sepal_Length  Sepal_Width  petal_length  petal_width  species
# 0            True         True          True         True     True
# 1            True         True          True         True     True
# 2            True         True          True         True     True
# 3            True         True          True         True     True
# 4            True         True          True         True     True
# ..            ...          ...           ...          ...      ...
# 145          True         True          True         True     True
# 146          True         True          True         True     True
# 147          True         True          True         True     True
# 148          True         True          True         True     True
# 149          True         True          True         True     True
#
# [150 rows x 5 columns]

# %%
df_clean.equals(df_new)
# Out:
# True

# %% [markdown]
# 7. Save Subset to JSON: Create a subset of the cleaned Iris dataset. For example, you can select a specific number of rows or specific columns. Export this subset to a JSON file (e.g., iris_subset.json) using Pandas.

# %%
df_clean["species"].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
subset_df = df_clean.loc[:4, ['sepal_length', 'sepal_width']]

# %%
df_iris_setosa = df_clean[df_clean["species"] == "Iris-setosa"]

# %%
df_iris_setosa["species"].value_counts()
# Out:
# species
# Iris-setosa    50
# Name: count, dtype: int64

# %%
df_iris_setosa.to_json("iris_subset.json")

# %%
df_iris = pd.read_json("iris_subset.json")

# %%
df_iris
# Out:
#     Sepal_Length  Sepal_Width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...
