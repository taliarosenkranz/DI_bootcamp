# %% [markdown]
# 🌟Exercise 1: Introduction to Data Analysis (Easy)

# %% [markdown]
# - What is data analysis?
#     - understanding the data, creating meaningful insights out of it
# - Why is data analysis important in modern contexts?
#     - Data drivene decision making is based on it
# - List and describe three areas where data analysis is applied today.
#     1. marketing to target the right people
#     2. finance to observe sales trends
#     3. product developent for analyzing which version of the product is best

# %% [markdown]
# 🌟Exercise 2: Dataset Loading and Initial Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_health = pd.read_csv("Mental health Depression disorder Data.csv")
df_sleep = pd.read_csv("Time Americans Spend Sleeping.csv")
df_cc = pd.read_csv("crx.csv")
# Out:
# <ipython-input-8-f74595543ac2>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_health = pd.read_csv("Mental health Depression disorder Data.csv")

# %%
df_health.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
df_health.describe()
# Out:
#                index  Anxiety disorders (%)  Drug use disorders (%)  \
# count  108553.000000            6468.000000             6468.000000
# mean    54276.000000               3.989921                0.862278
# std     31336.696223               1.167526                0.460679
# min         0.000000               2.023393                0.383650
# 25%     27138.000000               3.188824                0.535064
# 50%     54276.000000               3.554373                0.726430
# 75%     81414.000000               4.682163                0.940157
# max    108552.000000               8.967330                3.452476
#
#        Depression (%)  Alcohol use disorders (%)
# count     6468.000000                6468.000000
# mean         3.497654                   1.585821
# std          0.655859                   0.860283
# min          2.139903                   0.446940
# 25%          3.005529                   0.993685
# 50%          3.499606                   1.479936
# ...

# %%
df_sleep.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
df_sleep.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %%
df_cc.head(10)
# Out:
#    b  30.83       0  u  g   w  v   1.25  t t.1  01  f g.1  00202    0.1  +
# 0  a  58.67   4.460  u  g   q  h  3.040  t   t   6  f   g  00043    560  +
# 1  a  24.50   0.500  u  g   q  h  1.500  t   f   0  f   g  00280    824  +
# 2  b  27.83   1.540  u  g   w  v  3.750  t   t   5  t   g  00100      3  +
# 3  b  20.17   5.625  u  g   w  v  1.710  t   f   0  f   s  00120      0  +
# 4  b  32.08   4.000  u  g   m  v  2.500  t   f   0  t   g  00360      0  +
# 5  b  33.17   1.040  u  g   r  h  6.500  t   f   0  t   g  00164  31285  +
# 6  a  22.92  11.585  u  g  cc  v  0.040  t   f   0  f   g  00080   1349  +
# 7  b  54.42   0.500  y  p   k  h  3.960  t   f   0  f   g  00180    314  +
# 8  b  42.50   4.915  y  p   w  v  3.165  t   f   0  t   g  00052   1442  +
# 9  b  22.08   0.830  u  g   c  h  2.165  f   f   0  t   g  00128      0  +

# %%
df_cc.describe()
# Out:
#                 0        1.25          01            0.1
# count  689.000000  689.000000  689.000000     689.000000
# mean     4.765631    2.224819    2.402032    1018.862119
# std      4.978470    3.348739    4.866180    5213.743149
# min      0.000000    0.000000    0.000000       0.000000
# 25%      1.000000    0.165000    0.000000       0.000000
# 50%      2.750000    1.000000    0.000000       5.000000
# 75%      7.250000    2.625000    3.000000     396.000000
# max     28.000000   28.500000   67.000000  100000.000000

# %% [markdown]
# 🌟Exercise 3: Identifying Data Types: categorize each column of it as either quantitative or qualitative and explain your reasoning.

# %%
df_sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB

# %%
cols = df_sleep.columns

# %%
cols
# Out:
# Index(['index', 'Year', 'Period', 'Avg hrs per day sleeping', 'Standard Error',
#        'Type of Days', 'Age Group', 'Activity', 'Sex'],
#       dtype='object')

# %%
[type(i) for i in cols]
# Out:
# [str, str, str, str, str, str, str, str, str]

# %% [markdown]
# quantutative numberical, qualitative string like types. If a number is saved within '' quotationmarks, it will be understood as qualitative too. Quantitative data can be analyzed faster. Qualitative will need to be converted into some kind of numerical state.

# %% [markdown]
# 🌟Exercise 4: Exploring Data Types

# %%
df_iris = pd.read_csv("IRIS.csv")
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# - float data types are quantitative as these are like decimals
# - object data tyes are qualitative

# %%
iris_cols = df_iris.columns

# %%
[type(i) for i in iris_cols]
# Out:
# [str, str, str, str, str]

# %%
df_iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# 🌟Exercise 5: Basic Data Analysis with Google Colab

# %%
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print("mean", df_iris['sepal_length'].mean())
print("median", df_iris['sepal_length'].median())
print("mode", df_iris['sepal_length'].mode())
# Out:
# mean 5.843333333333334
# median 5.8
# mode 0    5.0
# Name: sepal_length, dtype: float64

# %%
plt.bar(df_iris["species"], df_iris["petal_length"])
plt.show()

# %% [markdown]
# 🌟Exercise 6: Basic Observation Skills in Data Analysis

# %%
df_sleep.head(20)
# Out:
#     index  Year  Period  Avg hrs per day sleeping  Standard Error  \
# 0       0  2003  Annual                      8.57           0.018
# 1       1  2004  Annual                      8.55           0.026
# 2       2  2005  Annual                      8.62           0.023
# 3       3  2006  Annual                      8.63           0.024
# 4       4  2007  Annual                      8.57           0.024
# 5       5  2008  Annual                      8.60           0.023
# 6       6  2009  Annual                      8.67           0.023
# 7       7  2010  Annual                      8.67           0.024
# 8       8  2011  Annual                      8.71           0.026
# 9       9  2012  Annual                      8.73           0.026
# 10     10  2013  Annual                      8.74           0.027
# 11     11  2014  Annual                      8.80           0.025
# 12     12  2015  Annual                      8.83           0.027
# ...

# %%
df_sleep["Sex"].sort_values().unique()
# Out:
# array(['Both', 'Men', 'Women'], dtype=object)

# %%
df_sleep["Age Group"].sort_values().unique()
# Out:
# array(['15 to 24 years', '15 years and over', '25 to 34 years',
#        '35 to 44 years', '45 to 54 years', '55 to 64 years',
#        '65 years and over'], dtype=object)

# %% [markdown]
# Interesting to analyze:
# - trend of sleep hours based on age groups
# - have the average sleeoing hours increased or descreased over the years in a consistant manner
